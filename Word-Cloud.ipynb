# %% [markdown]
# # Word Clouds

# %% [markdown]
# # 🧠 Word Clouds Project – IBM Data Science Lab
#
# This project is part of the IBM Data Science Professional Certificate program, designed to explore and visualize textual data using **Word Clouds**. The notebook demonstrates how to process and represent word frequency patterns from text using Python libraries.
#
# ## 🎯 Objectives
#
# - Learn how to process and clean raw text data.
# - Generate word clouds to visually represent the most frequent words.
# - Understand how word clouds can provide quick insights into text content.
# - Apply basic text preprocessing such as lowercasing, stopword removal, and tokenization.
#
# ## 📌 Summary
#
# In this lab, I worked with a raw text block to:
# - Clean the text by removing punctuations and converting it to lowercase.
# - Remove commonly used stopwords that add little value to textual analysis.
# - Generate a **Word Cloud** using the `wordcloud` library to display word frequency in a visual format.
# - Customize the appearance of the word cloud with different shapes, colors, and dimensions.
#
# This exercise helps build a foundation in **text analytics** and **natural language processing (NLP)** by using visual tools to extract meaning from unstructured data.
#
# ## 🛠 Tools & Libraries
#
# - Python
# - `wordcloud`
# - `matplotlib`
# - `collections` (for `Counter`)
# - `re` (regular expressions)
# - `nltk` (Natural Language Toolkit)
#
# ## 📊 Sample Output
#
# The word cloud created in the project highlights the most frequent words in the input text, with larger words representing higher frequency.
#
# ## 📂 Project Status
#
# ✅ Completed
# 🧪 Lab-based project from IBM Skills Network
# 🧠 Open for future enhancement (e.g., using large text files, adding interactivity, or integrating with web apps)

# %% [markdown]
# # Import Libraries<a id="0"></a>

# %%
# !pip install matplotlib
# !pip install pandas

# %%
#Import and setup matplotlib:
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

#Import Primary Modules:
import numpy as np 
import pandas as pd
from PIL import Image 

#install seaborn and wordcloud
# !pip install seaborn wordcloud 

#import seaborn
import seaborn as sns

#import wordcloud
import wordcloud

# %% [markdown]
# Luckily, a Python package already exists in Python for generating `word` clouds. The package, called `word_cloud` was developed by **Andreas Mueller**. You can learn more about the package by following this [link](https://github.com/amueller/word_cloud/).
#
# Let's use this package to learn how to generate a word cloud for a given text document.

# %%
#First, let's install the package.
# !pip install wordcloud

# %%
#import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud imported!')
# Out:
# Wordcloud imported!

# %% [markdown]
# `Word` clouds are commonly used to perform high-level analysis and visualization of text data. We will work with an example that involves analyzing text data. Let's try to analyze a short novel written by **Lewis Carroll** titled *Alice's Adventures in Wonderland*. Let's go ahead and download a *.txt* file of the novel.

# %%
import urllib

# # open the file and read it into a variable alice_novel
alice_novel = urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/alice_novel.txt').read().decode("utf-8")

# %% [markdown]
# Next, let's use the stopwords that we imported from `word_cloud`. We use the function *set* to remove any redundant stopwords.

# %%
stopwords = set(STOPWORDS)

# %% [markdown]
# Create a word cloud object and generate a word cloud. For simplicity, let's generate a word cloud using only the first 2000 words in the novel.

# %%
#if you get attribute error while generating worldcloud, upgrade Pillow and numpy using below code
#%pip install --upgrade Pillow 
#%pip install --upgrade numpy

# %%
# instantiate a word cloud object
alice_wc = WordCloud()

# generate the word cloud
alice_wc.generate(alice_novel)

# %% [markdown]
# Awesome! Now that the `word` cloud is created, let's visualize it.

# %%
# display the word cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Interesting! So in the first 2000 words in the novel, the most common words are **Alice**, **said**, **little**, **Queen**, and so on. Let's resize the cloud so that we can see the less frequent words a little better.

# %%
fig = plt.figure(figsize=(14, 18))

# display the cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Much better! However, **said** isn't really an informative word. So let's add it to our stopwords and re-generate the cloud.

# %%
stopwords.add('said') # add the words said to stopwords

# re-generate the word cloud
alice_wc.generate(alice_novel)

# display the cloud
fig = plt.figure(figsize=(14, 18))

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Excellent! This looks really interesting! Another cool thing you can implement with the `word_cloud` package is superimposing the words onto a mask of any shape. Let's use a mask of Alice and her rabbit. We already created the mask for you, so let's go ahead and download it and call it *alice_mask.png*.

# %%
#save mask to alice_mask
alice_mask = np.array(Image.open(urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/images/alice_mask.png')))

# %% [markdown]
# Let's take a look at how the mask looks like.

# %%
fig = plt.figure(figsize=(14, 18))

plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Shaping the `word` cloud according to the mask is straightforward using `word_cloud` package. For simplicity, we will continue using the first 2000 words in the novel.

# %%
# instantiate a word cloud object
alice_wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)

# generate the word cloud
alice_wc.generate(alice_novel)

# display the word cloud
fig = plt.figure(figsize=(14, 18))

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Really impressive!
